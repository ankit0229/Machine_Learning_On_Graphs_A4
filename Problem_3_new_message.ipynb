# %%
import networkx
import math
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", DeprecationWarning)
import dgl
import torch
import torch.nn as nn
import torch.nn.functional as F
import dgl.function as fn
from dgl.nn.pytorch import GraphConv

# %%
#Loading the karate club graph as a DGL graph
dgl_karate = dgl.DGLGraph(networkx.karate_club_graph())
#Initialising the 5 dimensional features with random values
dgl_karate.ndata['feat'] = torch.randn((34, 5))

# %%
#Defing the message and reduce function
#The source node is h and the output is on m
def message_func(edges):
    return {'m' : edges.src['h'] * edges.src['norm']}

reduce_func = fn.sum('m', 'h')

# %%
# Define the Graph_Convol module for doing the message passing and giving input features
class GraphConv(nn.Module):
    def __init__(self, in_feats, out_feats):
        super(GraphConv, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        
    def forward(self, g, inputs):
        #g is the graph and the inputs is the input node features
        #calculating norm
        val_norm = torch.reshape(torch.pow(g.in_degrees(g.nodes()).float(), -0.5), (-1,1))
        g.ndata['norm'] = val_norm
        #Performing linear transformation on the input features
        h = self.linear(inputs)
        #Setting the node features
        g.ndata['h'] = h
        #Doing message passing using the inbuilt message and reduce function
        g.update_all(message_func, reduce_func)
        #Getting the resultant node features and returning them after multiplying by norm value calculated above
        h = g.ndata.pop('h') * val_norm
        return h

# %%
class GCN(nn.Module):
    def __init__(self, in_feats, hidden_size, num_classes):
        super(GCN, self).__init__()
        #Defining the 2 layers of GCN along with the features size
        self.gcn1 = GraphConv(in_feats, hidden_size)
        self.gcn2 = GraphConv(hidden_size, num_classes)
    
    def forward(self, g, inputs):
        h = self.gcn1(g, inputs)
        #Applying Relu activation on the output of first layer before feeding to 2nd layer
        h = torch.relu(h)
        h = self.gcn2(g, h)
        return h

# %%
#Making the initail node features as one-hot encoding using node.eye
inputs = torch.eye(34)
#Assign labels to only instructor i.e. node 0 and president i.e. node 33 initially
labeled_nodes = torch.tensor([0, 33])  
#Assign them the 2 different labels i.e. 0 and 1
labels = torch.tensor([0, 1])
net = GCN(34, 5, 2)
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

all_logits = []
count_epochs = 300
for epoch in range(count_epochs):
    #Getting the vectors of raw i.e. non-normalized prediction probabilities
    logits = net(dgl_karate, inputs)
    #Storing the logits of each epoch in all_logits
    all_logits.append(logits.detach())
    #Applying softmax on the output
    logp = F.log_softmax(logits, 1)
    #As we know labels of only node 0 and 33 so computing loss for them only
    loss = F.nll_loss(logp[labeled_nodes], labels)
    
    #Running the optimizer
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    print('Epoch %d | Loss: %.4f' % (epoch, loss.item()))
# Out:
# Epoch 0 | Loss: 1.0689
# Epoch 1 | Loss: 1.0664
# Epoch 2 | Loss: 1.0639
# Epoch 3 | Loss: 1.0615
# Epoch 4 | Loss: 1.0590
# Epoch 5 | Loss: 1.0566
# Epoch 6 | Loss: 1.0541
# Epoch 7 | Loss: 1.0517
# Epoch 8 | Loss: 1.0493
# Epoch 9 | Loss: 1.0469
# Epoch 10 | Loss: 1.0445
# Epoch 11 | Loss: 1.0421
# Epoch 12 | Loss: 1.0397
# Epoch 13 | Loss: 1.0373
# Epoch 14 | Loss: 1.0349
# Epoch 15 | Loss: 1.0325
# Epoch 16 | Loss: 1.0302
# Epoch 17 | Loss: 1.0278
# Epoch 18 | Loss: 1.0254
# Epoch 19 | Loss: 1.0231
# Epoch 20 | Loss: 1.0208
# Epoch 21 | Loss: 1.0184
# Epoch 22 | Loss: 1.0161
# Epoch 23 | Loss: 1.0138
# Epoch 24 | Loss: 1.0114
# Epoch 25 | Loss: 1.0091
# Epoch 26 | Loss: 1.0068
# Epoch 27 | Loss: 1.0045
# Epoch 28 | Loss: 1.0023
# Epoch 29 | Loss: 1.0000
# Epoch 30 | Loss: 0.9977
# Epoch 31 | Loss: 0.9954
# Epoch 32 | Loss: 0.9932
# Epoch 33 | Loss: 0.9909
# Epoch 34 | Loss: 0.9886
# Epoch 35 | Loss: 0.9863
# Epoch 36 | Loss: 0.9841
# Epoch 37 | Loss: 0.9818
# Epoch 38 | Loss: 0.9794
# Epoch 39 | Loss: 0.9771
# Epoch 40 | Loss: 0.9748
# Epoch 41 | Loss: 0.9724
# Epoch 42 | Loss: 0.9701
# Epoch 43 | Loss: 0.9677
# Epoch 44 | Loss: 0.9653
# Epoch 45 | Loss: 0.9629
# Epoch 46 | Loss: 0.9605
# Epoch 47 | Loss: 0.9581
# Epoch 48 | Loss: 0.9557
# Epoch 49 | Loss: 0.9533
# Epoch 50 | Loss: 0.9508
# Epoch 51 | Loss: 0.9484
# Epoch 52 | Loss: 0.9460
# Epoch 53 | Loss: 0.9436
# Epoch 54 | Loss: 0.9411
# Epoch 55 | Loss: 0.9387
# Epoch 56 | Loss: 0.9362
# Epoch 57 | Loss: 0.9338
# Epoch 58 | Loss: 0.9313
# Epoch 59 | Loss: 0.9289
# Epoch 60 | Loss: 0.9264
# Epoch 61 | Loss: 0.9239
# Epoch 62 | Loss: 0.9215
# Epoch 63 | Loss: 0.9190
# Epoch 64 | Loss: 0.9165
# Epoch 65 | Loss: 0.9140
# Epoch 66 | Loss: 0.9115
# Epoch 67 | Loss: 0.9091
# Epoch 68 | Loss: 0.9066
# Epoch 69 | Loss: 0.9041
# Epoch 70 | Loss: 0.9016
# Epoch 71 | Loss: 0.8991
# Epoch 72 | Loss: 0.8966
# Epoch 73 | Loss: 0.8941
# Epoch 74 | Loss: 0.8916
# Epoch 75 | Loss: 0.8891
# Epoch 76 | Loss: 0.8866
# Epoch 77 | Loss: 0.8841
# Epoch 78 | Loss: 0.8815
# Epoch 79 | Loss: 0.8790
# Epoch 80 | Loss: 0.8765
# Epoch 81 | Loss: 0.8740
# Epoch 82 | Loss: 0.8714
# Epoch 83 | Loss: 0.8689
# Epoch 84 | Loss: 0.8664
# Epoch 85 | Loss: 0.8638
# Epoch 86 | Loss: 0.8613
# Epoch 87 | Loss: 0.8587
# Epoch 88 | Loss: 0.8562
# Epoch 89 | Loss: 0.8537
# Epoch 90 | Loss: 0.8511
# Epoch 91 | Loss: 0.8486
# Epoch 92 | Loss: 0.8460
# Epoch 93 | Loss: 0.8435
# Epoch 94 | Loss: 0.8409
# Epoch 95 | Loss: 0.8384
# Epoch 96 | Loss: 0.8358
# Epoch 97 | Loss: 0.8332
# Epoch 98 | Loss: 0.8307
# Epoch 99 | Loss: 0.8281
# Epoch 100 | Loss: 0.8256
# Epoch 101 | Loss: 0.8230
# Epoch 102 | Loss: 0.8205
# Epoch 103 | Loss: 0.8179
# Epoch 104 | Loss: 0.8154
# Epoch 105 | Loss: 0.8128
# Epoch 106 | Loss: 0.8102
# Epoch 107 | Loss: 0.8077
# Epoch 108 | Loss: 0.8051
# Epoch 109 | Loss: 0.8026
# Epoch 110 | Loss: 0.8000
# Epoch 111 | Loss: 0.7975
# Epoch 112 | Loss: 0.7949
# Epoch 113 | Loss: 0.7924
# Epoch 114 | Loss: 0.7899
# Epoch 115 | Loss: 0.7873
# Epoch 116 | Loss: 0.7848
# Epoch 117 | Loss: 0.7822
# Epoch 118 | Loss: 0.7797
# Epoch 119 | Loss: 0.7772
# Epoch 120 | Loss: 0.7746
# Epoch 121 | Loss: 0.7721
# Epoch 122 | Loss: 0.7696
# Epoch 123 | Loss: 0.7671
# Epoch 124 | Loss: 0.7646
# Epoch 125 | Loss: 0.7620
# Epoch 126 | Loss: 0.7595
# Epoch 127 | Loss: 0.7570
# Epoch 128 | Loss: 0.7545
# Epoch 129 | Loss: 0.7520
# Epoch 130 | Loss: 0.7495
# Epoch 131 | Loss: 0.7470
# Epoch 132 | Loss: 0.7445
# Epoch 133 | Loss: 0.7421
# Epoch 134 | Loss: 0.7396
# Epoch 135 | Loss: 0.7371
# Epoch 136 | Loss: 0.7346
# Epoch 137 | Loss: 0.7322
# Epoch 138 | Loss: 0.7297
# Epoch 139 | Loss: 0.7272
# Epoch 140 | Loss: 0.7248
# Epoch 141 | Loss: 0.7223
# Epoch 142 | Loss: 0.7199
# Epoch 143 | Loss: 0.7174
# Epoch 144 | Loss: 0.7150
# Epoch 145 | Loss: 0.7126
# Epoch 146 | Loss: 0.7101
# Epoch 147 | Loss: 0.7077
# Epoch 148 | Loss: 0.7053
# Epoch 149 | Loss: 0.7029
# Epoch 150 | Loss: 0.7005
# Epoch 151 | Loss: 0.6981
# Epoch 152 | Loss: 0.6957
# Epoch 153 | Loss: 0.6933
# Epoch 154 | Loss: 0.6909
# Epoch 155 | Loss: 0.6885
# Epoch 156 | Loss: 0.6862
# Epoch 157 | Loss: 0.6838
# Epoch 158 | Loss: 0.6814
# Epoch 159 | Loss: 0.6791
# Epoch 160 | Loss: 0.6767
# Epoch 161 | Loss: 0.6744
# Epoch 162 | Loss: 0.6720
# Epoch 163 | Loss: 0.6697
# Epoch 164 | Loss: 0.6673
# Epoch 165 | Loss: 0.6650
# Epoch 166 | Loss: 0.6627
# Epoch 167 | Loss: 0.6604
# Epoch 168 | Loss: 0.6581
# Epoch 169 | Loss: 0.6557
# Epoch 170 | Loss: 0.6534
# Epoch 171 | Loss: 0.6511
# Epoch 172 | Loss: 0.6488
# Epoch 173 | Loss: 0.6466
# Epoch 174 | Loss: 0.6443
# Epoch 175 | Loss: 0.6420
# Epoch 176 | Loss: 0.6397
# Epoch 177 | Loss: 0.6374
# Epoch 178 | Loss: 0.6352
# Epoch 179 | Loss: 0.6329
# Epoch 180 | Loss: 0.6306
# Epoch 181 | Loss: 0.6284
# Epoch 182 | Loss: 0.6261
# Epoch 183 | Loss: 0.6239
# Epoch 184 | Loss: 0.6216
# Epoch 185 | Loss: 0.6194
# Epoch 186 | Loss: 0.6171
# Epoch 187 | Loss: 0.6149
# Epoch 188 | Loss: 0.6126
# Epoch 189 | Loss: 0.6104
# Epoch 190 | Loss: 0.6081
# Epoch 191 | Loss: 0.6059
# Epoch 192 | Loss: 0.6037
# Epoch 193 | Loss: 0.6014
# Epoch 194 | Loss: 0.5992
# Epoch 195 | Loss: 0.5970
# Epoch 196 | Loss: 0.5948
# Epoch 197 | Loss: 0.5925
# Epoch 198 | Loss: 0.5903
# Epoch 199 | Loss: 0.5881
# Epoch 200 | Loss: 0.5858
# Epoch 201 | Loss: 0.5836
# Epoch 202 | Loss: 0.5813
# Epoch 203 | Loss: 0.5791
# Epoch 204 | Loss: 0.5769
# Epoch 205 | Loss: 0.5746
# Epoch 206 | Loss: 0.5724
# Epoch 207 | Loss: 0.5702
# Epoch 208 | Loss: 0.5679
# Epoch 209 | Loss: 0.5657
# Epoch 210 | Loss: 0.5634
# Epoch 211 | Loss: 0.5612
# Epoch 212 | Loss: 0.5590
# Epoch 213 | Loss: 0.5567
# Epoch 214 | Loss: 0.5545
# Epoch 215 | Loss: 0.5522
# Epoch 216 | Loss: 0.5500
# Epoch 217 | Loss: 0.5477
# Epoch 218 | Loss: 0.5455
# Epoch 219 | Loss: 0.5433
# Epoch 220 | Loss: 0.5410
# Epoch 221 | Loss: 0.5388
# Epoch 222 | Loss: 0.5365
# Epoch 223 | Loss: 0.5342
# Epoch 224 | Loss: 0.5320
# Epoch 225 | Loss: 0.5297
# Epoch 226 | Loss: 0.5274
# Epoch 227 | Loss: 0.5252
# Epoch 228 | Loss: 0.5229
# Epoch 229 | Loss: 0.5206
# Epoch 230 | Loss: 0.5184
# Epoch 231 | Loss: 0.5161
# Epoch 232 | Loss: 0.5138
# Epoch 233 | Loss: 0.5115
# Epoch 234 | Loss: 0.5093
# Epoch 235 | Loss: 0.5070
# Epoch 236 | Loss: 0.5047
# Epoch 237 | Loss: 0.5024
# Epoch 238 | Loss: 0.5002
# Epoch 239 | Loss: 0.4979
# Epoch 240 | Loss: 0.4956
# Epoch 241 | Loss: 0.4933
# Epoch 242 | Loss: 0.4910
# Epoch 243 | Loss: 0.4887
# Epoch 244 | Loss: 0.4865
# Epoch 245 | Loss: 0.4842
# Epoch 246 | Loss: 0.4819
# Epoch 247 | Loss: 0.4796
# Epoch 248 | Loss: 0.4773
# Epoch 249 | Loss: 0.4750
# Epoch 250 | Loss: 0.4727
# Epoch 251 | Loss: 0.4704
# Epoch 252 | Loss: 0.4681
# Epoch 253 | Loss: 0.4658
# Epoch 254 | Loss: 0.4636
# Epoch 255 | Loss: 0.4613
# Epoch 256 | Loss: 0.4590
# Epoch 257 | Loss: 0.4567
# Epoch 258 | Loss: 0.4544
# Epoch 259 | Loss: 0.4521
# Epoch 260 | Loss: 0.4499
# Epoch 261 | Loss: 0.4476
# Epoch 262 | Loss: 0.4453
# Epoch 263 | Loss: 0.4430
# Epoch 264 | Loss: 0.4407
# Epoch 265 | Loss: 0.4385
# Epoch 266 | Loss: 0.4362
# Epoch 267 | Loss: 0.4339
# Epoch 268 | Loss: 0.4317
# Epoch 269 | Loss: 0.4294
# Epoch 270 | Loss: 0.4272
# Epoch 271 | Loss: 0.4249
# Epoch 272 | Loss: 0.4227
# Epoch 273 | Loss: 0.4204
# Epoch 274 | Loss: 0.4182
# Epoch 275 | Loss: 0.4159
# Epoch 276 | Loss: 0.4137
# Epoch 277 | Loss: 0.4114
# Epoch 278 | Loss: 0.4092
# Epoch 279 | Loss: 0.4070
# Epoch 280 | Loss: 0.4047
# Epoch 281 | Loss: 0.4025
# Epoch 282 | Loss: 0.4003
# Epoch 283 | Loss: 0.3981
# Epoch 284 | Loss: 0.3959
# Epoch 285 | Loss: 0.3936
# Epoch 286 | Loss: 0.3914
# Epoch 287 | Loss: 0.3892
# Epoch 288 | Loss: 0.3871
# Epoch 289 | Loss: 0.3849
# Epoch 290 | Loss: 0.3827
# Epoch 291 | Loss: 0.3805
# Epoch 292 | Loss: 0.3783
# Epoch 293 | Loss: 0.3762
# Epoch 294 | Loss: 0.3740
# Epoch 295 | Loss: 0.3719
# Epoch 296 | Loss: 0.3697
# Epoch 297 | Loss: 0.3676
# Epoch 298 | Loss: 0.3654
# Epoch 299 | Loss: 0.3633

# %%
#Now plotting the 2-D embeddings at some epochs
for i in range(0,300, +69):
    #Getting all 2-D embeddings for the particular epoch
    x = all_logits[i]
    x_cord_0 = [float(x[0][0])]
    y_cord_0 = [float(x[0][1])]
    x_cord_33 = [float(x[33][0])]
    y_cord_33 = [float(x[33][1])]
    
    for j in range(1,33):
        a_cord = float(x[j][0])
        b_cord = float(x[j][1])
        #Finding the community to which node belongs according to probabilities
        if a_cord > b_cord:
            x_cord_0.append(a_cord)
            y_cord_0.append(b_cord)
        else:
            x_cord_33.append(a_cord)
            y_cord_33.append(b_cord)
    
    print(f"Embeddings at epoch {i}")
    plt.style.use('seaborn-darkgrid')
    plt.figure(figsize = (7,7))
    plt.scatter(x_cord_0, y_cord_0,color = 'r', label='With Mr. Hi i.e. node 0')  
    plt.scatter(x_cord_33, y_cord_33, color = 'g', label='With President i.e. node 33')                               

    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.legend()
    plt.show()
# Out:
# Embeddings at epoch 0
# Embeddings at epoch 69
# Embeddings at epoch 138
# Embeddings at epoch 207
# Embeddings at epoch 276

# %%
#Finding accuracy of the model
from sklearn.metrics import accuracy_score
temp_karate = networkx.karate_club_graph()
#Preparing a list of ground truth communities of all the nodes
actual_labels = []
for z in range(1,33):
    comm = temp_karate.nodes[z]['club']
    if comm == 'Mr. Hi':
        actual_labels.append(0)
    else:
        actual_labels.append(33)

predicted_labels = []
last_logit = all_logits[count_epochs-1]
for r in range(1,33):
    if float(last_logit[r][0]) > float(last_logit[r][1]):
        predicted_labels.append(0)
    else:
        predicted_labels.append(33)
        
score_acc = accuracy_score(actual_labels, predicted_labels)

# %%
print(f"The accuracy of the model in predicting communities = {score_acc}")
# Out:
# The accuracy of the model in predicting communities = 0.9375
